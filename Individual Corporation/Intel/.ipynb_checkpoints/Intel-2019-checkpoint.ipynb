# %%
# import basic libraries
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import scipy.stats as stats
from warnings import filterwarnings

# import data reader
from pandas_datareader import data, wb
import pandas_datareader.data as web

# import time stamps library
from datetime import datetime

# import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# give white grid bacground
sns.set_style('whitegrid')

# %%
# set the starting date (1 January 2019) and ending date (31 December 2019) of the analysis
end = datetime(year = 2019, month = 12, day = 31)

start = datetime(end.year, month = 1, day = 1)

# %%
# fetching the data from yahoo
globals()['INTC'] = web.DataReader('INTC', 'yahoo', start, end)

# %%
# description of Apple stock
INTC.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean    51.798380   50.850118   51.300830   51.357628  2.189940e+07
# std      4.326067    4.392044    4.364993    4.380942  9.623841e+06
# min     44.459999   42.860001   43.349998   43.459999  6.313200e+06
# 25%     48.000000   47.040001   47.560001   47.540001  1.632010e+07
# 50%     51.669998   50.560001   51.080002   51.040001  1.915450e+07
# 75%     54.799999   54.000000   54.419998   54.509998  2.552230e+07
# max     60.480000   59.900002   59.990002   60.080002  8.645570e+07
#
#         Adj Close
# count  253.000000
# mean    49.918972
# std      4.417352
# min     42.195328
# 25%     46.087029
# 50%     49.729515
# 75%     52.601627
# max     59.048733

# %%
# column information of Apple stock
INTC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2018-12-31 to 2019-12-31
# Data columns (total 6 columns):
# High         253 non-null float64
# Low          253 non-null float64
# Open         253 non-null float64
# Close        253 non-null float64
# Volume       253 non-null float64
# Adj Close    253 non-null float64
# dtypes: float64(6)
# memory usage: 13.8 KB

# %%
# plot of adjusted close price of Apple
INTC['Adj Close'].plot(legend = True, figsize = (10, 4), label = 'Intel', color = '#2832C2')

# %%
# plot of volume traded in Apple
INTC['Volume'].plot(legend = True, figsize = (10, 4), label = 'Intel', color = '#2832C2')

# %%
# scatterplot
plt.scatter(x = INTC['Adj Close'], y = INTC['Volume'], color = '#2832C2')

# labeling
plt.xlabel('Adjusted Closing Price')
plt.ylabel('Volume')
plt.title('Correlation Between\nAdjusted Closing Price and Volume')

# trendline
adj_vol_fit = np.polyfit(INTC['Adj Close'], INTC['Volume'], 1)
adj_vol_polinom = np.poly1d(adj_vol_fit)
plt.plot(INTC['Adj Close'], adj_vol_polinom(INTC['Adj Close']), 'k-')

# %%
# calculating moving average
ma_day = [10, 20, 50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    
    INTC[column_name] = DataFrame.rolling(INTC['Adj Close'], ma).mean()
    
# plot the moving average
INTC[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots = False, figsize = (10, 4), title = 'Microsoft')

# %%
# creating percentage change
INTC['Daily Return'] = INTC['Adj Close'].pct_change()

# plotting the daily return stock in percentage change
INTC[['Daily Return']].plot(
    subplots = False, 
    figsize = (10, 4), 
    legend = True, 
    linestyle = '-', 
    marker = 'o', 
    color = '#2832C2',
    title = 'Intel'
)

# %%
# plotting the daily return stock on average
sns.distplot(
    INTC[['Daily Return']].dropna(), 
    hist = True,
    kde = True,
    kde_kws = {'linewidth': 5,
               'shade': True
              }, 
    color = '#2832C2',
    label = 'Intel'
)

# %%
# getting only the daily return in each technology corporation list
closing = web.DataReader('INTC', 'yahoo', start, end)['Adj Close'].to_frame()
closing.head()
# Out:
#             Adj Close
# Date
# 2018-12-31  45.001755
# 2019-01-02  45.145596
# 2019-01-03  42.662006
# 2019-01-04  45.279839
# 2019-01-07  45.490799

# %%
# identifying the percentage change in daily returns
tech_returns = closing.pct_change()
tech_returns.head()
# Out:
#             Adj Close
# Date
# 2018-12-31        NaN
# 2019-01-02   0.003196
# 2019-01-03  -0.055013
# 2019-01-04   0.061362
# 2019-01-07   0.004659

# %%
# drop NaN value from return columns
rets = tech_returns.dropna()

# set the size of points
area = np.pi*350

# scatter plot and labeling
plt.scatter(rets.mean(), rets.std(), s = area)
plt.xlabel('Expected Return')
plt.ylabel('Risk')
plt.xlim(-0.002, 0.005)
plt.ylim(0.010, 0.020)

# annotation
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), 
        xytext = (100, 100), 
        textcoords = 'offset points', 
        ha = 'right',
        va = 'bottom',
        arrowprops = dict(
            arrowstyle = 'simple',
            connectionstyle = 'arc3, rad = -0.3'
        )
    )

# %%
rets.head()
# Out:
#             Adj Close
# Date
# 2019-01-02   0.003196
# 2019-01-03  -0.055013
# 2019-01-04   0.061362
# 2019-01-07   0.004659
# 2019-01-08   0.006324

# %%
# applying bootstrap method 
INTC_rets = rets.quantile(0.05)
print('95% of the times of simulations, the worst daily loss in investing on Intel would not exceed {:.3f}%'.format(100 * abs(INTC_rets['Adj Close'])))
# Out:
# 95% of the times of simulations, the worst daily loss in investing on Intel would not exceed 2.484%

# %%
# setting up the necessary initial variables
days = 365
dt = 1 / days

INTC_mu = rets.mean()
INTC_sigma = rets.std()

# running Monte-Carlo simulation
def stock_monte_carlo(start_price, days, mu, sigma):
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days):
        shock[x] = np.random.normal(loc = mu * dt, 
                                    scale = sigma * np.sqrt(dt)
                                   )
        drift[x] = mu * dt
        price[x] = price[x - 1] + (price[x - 1] * (drift[x] + shock[x]))
    return price

# 100 simulations for Apple
INTC_start_price = INTC['Open'][0]

for run in range(100):
    INTC_simulation = stock_monte_carlo(INTC_start_price, days, INTC_mu, INTC_sigma)
    plt.plot(INTC_simulation)

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte-Carlo Simulation for Intel')
# Out:
# Text(0.5, 1.0, 'Monte-Carlo Simulation for Intel')

# %%
q = np.percentile(INTC_simulation, 1)
sns.distplot(
    INTC_simulation, 
    kde_kws = {'linewidth': 5}, 
    color = '#2832C2')

# starting price
plt.figtext(0.6, 0.8,s="Start price: $%.2f" %INTC_start_price)
# mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % INTC_simulation.mean())

# variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (INTC_start_price - q,))

# display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# title
plt.title(u"Final price distribution for Intel Stock after %s days" % days, weight='bold');
