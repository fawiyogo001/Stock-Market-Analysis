# %%
# import basic libraries
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import scipy.stats as stats
from warnings import filterwarnings

# import data reader
from pandas_datareader import data, wb
import pandas_datareader.data as web

# import time stamps library
from datetime import datetime

# import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# give white grid bacground
sns.set_style('whitegrid')

# %%
# set the starting date (1 January 2019) and ending date (31 December 2019) of the analysis
end = datetime(year = 2019, month = 12, day = 31)

start = datetime(end.year, month = 1, day = 1)

# %%
# fetching the data from yahoo
globals()['AAPL'] = web.DataReader('AAPL', 'yahoo', start, end)

# %%
# description of Apple stock
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   209.632214  206.074822  207.674071  208.056284  2.805852e+07
# std     34.562977   34.380412   34.445268   34.616376  1.081148e+07
# min    145.720001  142.000000  143.979996  142.190002  1.136200e+07
# 25%    187.330002  182.850006  184.850006  185.720001  2.099050e+07
# 50%    204.490005  201.559998  203.119995  202.899994  2.588170e+07
# 75%    224.580002  220.789993  223.059998  223.589996  3.204650e+07
# max    293.970001  289.519989  291.119995  293.649994  9.131220e+07
#
#         Adj Close
# count  253.000000
# mean   205.395530
# std     35.029156
# min    139.125412
# 25%    182.889603
# 50%    200.321732
# 75%    221.393372
# max    291.638000

# %%
# column information of Apple stock
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2018-12-31 to 2019-12-31
# Data columns (total 6 columns):
# High         253 non-null float64
# Low          253 non-null float64
# Open         253 non-null float64
# Close        253 non-null float64
# Volume       253 non-null float64
# Adj Close    253 non-null float64
# dtypes: float64(6)
# memory usage: 13.8 KB

# %%
# plot of adjusted close price of Apple
AAPL['Adj Close'].plot(legend = True, figsize = (10, 4), label = 'Apple', color = '#555555')

# %%
# plot of volume traded in Apple
AAPL['Volume'].plot(legend = True, figsize = (10, 4), label = 'Apple', color = '#555555')

# %%
# scatterplot
plt.scatter(x = AAPL['Adj Close'], y = AAPL['Volume'], color = '#555555')

# labeling
plt.xlabel('Adjusted Closing Price')
plt.ylabel('Volume')
plt.title('Correlation Between\nAdjusted Closing Price and Volume')

# trendline
adj_vol_fit = np.polyfit(AAPL['Adj Close'], AAPL['Volume'], 1)
adj_vol_polinom = np.poly1d(adj_vol_fit)
plt.plot(AAPL['Adj Close'], adj_vol_polinom(AAPL['Adj Close']), 'k-')

# %%
# calculating moving average
ma_day = [10, 20, 50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    
    AAPL[column_name] = DataFrame.rolling(AAPL['Adj Close'], ma).mean()
    
# plot the moving average
AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(subplots = False, figsize = (10, 4), title = 'Apple')

# %%
# creating percentage change
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change()

# plotting the daily return stock in percentage change
AAPL[['Daily Return']].plot(
    subplots = False, 
    figsize = (10, 4), 
    legend = True, 
    linestyle = '-', 
    marker = 'o', 
    color = '#555555',
    title = 'Apple'
)

# %%
# plotting the daily return stock on average
sns.distplot(
    AAPL[['Daily Return']].dropna(), 
    hist = True,
    kde = True,
    kde_kws = {'linewidth': 5,
               'shade': True
              }, 
    color = '#555555',
    label = 'Apple'
)

# %%
# getting only the daily return in each technology corporation list
closing = web.DataReader('AAPL', 'yahoo', start, end)['Adj Close'].to_frame()
closing.head()
# Out:
#              Adj Close
# Date
# 2018-12-31  154.340271
# 2019-01-02  154.516388
# 2019-01-03  139.125412
# 2019-01-04  145.064575
# 2019-01-07  144.741714

# %%
# identifying the percentage change in daily returns
tech_returns = closing.pct_change()
tech_returns.head()
# Out:
#             Adj Close
# Date
# 2018-12-31        NaN
# 2019-01-02   0.001141
# 2019-01-03  -0.099607
# 2019-01-04   0.042689
# 2019-01-07  -0.002226

# %%
# drop NaN value from return columns
rets = tech_returns.dropna()

# set the size of points
area = np.pi*350

# scatter plot and labeling
plt.scatter(rets.mean(), rets.std(), s = area)
plt.xlabel('Expected Return')
plt.ylabel('Risk')
plt.xlim(-0.002, 0.005)
plt.ylim(0.010, 0.020)

# annotation
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), 
        xytext = (100, 100), 
        textcoords = 'offset points', 
        ha = 'right',
        va = 'bottom',
        arrowprops = dict(
            arrowstyle = 'simple',
            connectionstyle = 'arc3, rad = -0.3'
        )
    )

# %%
rets.head()
# Out:
#             Adj Close
# Date
# 2019-01-02   0.001141
# 2019-01-03  -0.099607
# 2019-01-04   0.042689
# 2019-01-07  -0.002226
# 2019-01-08   0.019063

# %%
# applying bootstrap method 
AAPL_rets = rets.quantile(0.05)
print('95% of the times of simulations, the worst daily loss in investing on Apple would not exceed {:.3f}%'.format(100 * abs(AAPL_rets['Adj Close'])))
# Out:
# 95% of the times of simulations, the worst daily loss in investing on Apple would not exceed 2.066%

# %%
# setting up the necessary initial variables
days = 365
dt = 1 / days

AAPL_mu = rets.mean()
AAPL_sigma = rets.std()

# running Monte-Carlo simulation
def stock_monte_carlo(start_price, days, mu, sigma):
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days):
        shock[x] = np.random.normal(loc = mu * dt, 
                                    scale = sigma * np.sqrt(dt)
                                   )
        drift[x] = mu * dt
        price[x] = price[x - 1] + (price[x - 1] * (drift[x] + shock[x]))
    return price

# 100 simulations for Apple
AAPL_start_price = AAPL['Open'][0]

for run in range(100):
    AAPL_simulation = stock_monte_carlo(AAPL_start_price, days, AAPL_mu, AAPL_sigma)
    plt.plot(AAPL_simulation)

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte-Carlo Simulation for Apple')
# Out:
# Text(0.5, 1.0, 'Monte-Carlo Simulation for Apple')

# %%
q = np.percentile(AAPL_simulation, 1)
sns.distplot(
    AAPL_simulation, 
    kde_kws = {'linewidth': 5}, 
    color = '#555555')

# starting price
plt.figtext(0.6, 0.8,s="Start price: $%.2f" %AAPL_start_price)
# mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % AAPL_simulation.mean())

# variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (AAPL_start_price - q,))

# display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# title
plt.title(u"Final price distribution for Apple Stock after %s days" % days, weight='bold');
